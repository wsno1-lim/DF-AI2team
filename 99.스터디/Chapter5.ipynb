# %% [markdown]
# *   CHAPTER 5. 금융에서의 머신러닝
#
#    -- 머신러닝을 구현할 때 알아야 하는 기본적인 내용에 대한 설명
#
#
#
# 1.   머신러닝 알고리즘이란?
#
#   -- 학술적이지도 엄격하지도 못하지만, 상대적으로 근래에 등장한 '딥러닝'과 구분하기 위해사용
#
#
# 2.   데이터 전치리
#
#   -- 노이즈가 유달리 많은 금융 데이터를 좀 더 효과적으로 활용하기 위한 노이즈 제거 방법 소개
#
#
# 3.  평가
#
#   -- 교차검증에대한 내용과 좀 더 정확한 지표 활용을 위한 팁
#
#
# 4.   백테스팅
#
#   -- 아직 해결되지 못한 영역(논란많음)

# %% [markdown]
# *   5.1 왜 머신러닝을 활용해야 하는가?
#
#
# 1.   우리가 아는 금융에 대한 종래의 관념이 무너진 것(핀테크 -> 테크핀, 카카오뱅크, 네이버페이, 토스뱅크 등)
#
# 2.   모니터링해야 하는 정보(데이터)가 기하급수적으로 증가
#
# 3.   투자 의사결정을 내리는데 속도가 중요해진 변화
# 4.   투자자들의 요구가 다양해짐
#
#
#
#   -- 다양한 머신러닝 방법을 도입해 기존의 계량 경제학이나 금융 공학 기법으로 풀지못한 시장 예측 문제를 앞다퉈 해결하려고 시도하지만, 소스가 제한적인 만큼 어떤 시도들이 진행되고 있는지를 알아보기 위해 공개된 학술 논문 검색 필요

# %% [markdown]
# *   5.2 머신러닝 알고리즘 소개
#
#  -- 이 책은 데이터 분석에 자주 활용 되는 알고리즘 위주로 정리
#
#
# 1.   지도학습(supervised learning)
#
#    -- 샘플 데이터를 활용해 트렌드 기반의 예측
#
#    1) Support Vector Machine(SVM)
#
#    런닝머신의 한 시대를 풍미한 알고리즘..오래전에 탄생한 알고리즘인 만큼 금융 데이터를 활용한 연구도 비교적 많은편. 또, 주가 데이터 예측 논문에서 가장 많이 다룬 알고리즘
#
#   -- 장점 : 데이터의 특성이 많지 않더라도 (상대적으로) 좋은 성능을 낼 수 있음
#
#  -- 단점 : 샘플이 많을 떄는 속도와 메모리 관점에서 이슈, 데이터 전처리와 매개변수 설정에 신경을 많이 써야함, 해석 가능성이 약함
#
#   2) 트리 기반 모델
#
#
#       P.177 [그림 5-2]
#
#       앙상블 학습이란?
#       어떤 데이터가 주어졌을 때(분류 문제), 그 데이터가 어떤 클래스에 속할지를 일련의 예측기(Classifier), 즉 분류나 회귀 모델로부터 예측들을 모아서 결정하는 방식
#
#       배깅이란?
#       훈련 세트에서 중복을 허용하여 샘플링하는 방식..
#
#       부스팅이란?
#       약한 분류기를 결합해 강한 분류기 생성(연속적인 weak learner, 바로 직전 weak learner의 error를 반영해 현재 weak learner를 잡겠다는 아이디어)
#
#
#
# > 가. 랜덤 포레스트
#
# > -- 결정 트리들로 이루어지기 때문에 각각의 결정 트리들을 학습하는 과정이 필요.
# 랜덤 포레스트 방식에서는 무작위로 선택한 특성 후보들 중에서 최적의 특성(노드 분할의 기준이 되는)을 찾는 방법을 사용
#
#
# >  -- 장점 :
# 몇몇의 결정트리들이 과대적합되거나 과소적합되어도 해당하는 오차가 상대적으로 무시되는 경향이 있어서 일반적으로 의사결정트리 하나를 사용한 모델보다 좋은 성능
#
# >  -- 주의점 :  트리들의 상관관계를 줄여야 모델의 정확도가 높아진다.. 그래서 전처리 작업에서 상관계수가 높은 변수들은 걸러주는것이 좋다
#
# >  -- 단점 :
# 주기성이나 경향성이 있는 데이터에서 성능이 떨어지는 경향, 차원이 높고 희소한 데이터(텍스트데이터)에는 잘 작동하지 않는다.
#
#
#   3) 부스팅 기반 모델
#
#   부스티은 약한 분류기를 경합할 때 틀린 것에 가중치를 부여하여 강한 학습기를 만들어 가는데, 이때 가중치를 부여하는 방식에 따라 분류되는 알고리즘이 달라짐
#
#
# ![경사하강법.png](data:image/png;base64,...)

# %% [markdown]
# 2. 비지도 학습
#
#   많은 변수들간의 관계 파악
#
#
#   -- 차원 축소와 클러스터링
#   차원 축소를 통해 금융 데이터에 존재하는 많은 노이즈를 제거하려는 시도가 계속되고 있으나, 차원을 축소하게 되면 해석력에 문제가 생겨 사용하기 어려움
#
#   클러스터링은 비슷하거나 공통의 특성을 가진 자산이나 종목을 찾아서 포트폴리오를 보다 더 안정적으로 만드려는 목적

# %% [markdown]
# *   5.3 금융 시계열 데이터에 대한 교차 검증 방법
# >검증 셋을 분리하고 검증을 진행하는 단계.. 머신러닝 모델을 만들 때 교차 검증은 반드시 거쳐야할 단계이다.
# >>
# 단, 테스트 셋을 검증 셋으로 사용하면 테스트셋에 과적합이 되기 떄문에 안된다!(2019년도 수능 시험문제 테스트에 과적합 시 2020년도 수능 문제 시 적합하지않음)
# >>
# 그러므로 테스트셋은 마지막 단계에서 단 한번만 사용
# >>
# 종류로는 홀드아웃(holdout) 방법, 원리브아웃(One Leave Out) 방법, k-fold 교차 검증 방법 등 존재
#
#
#
# 1.   walk-forward 교차검증과 blocking walk forward 교차 검증
# >   -- walk-forward 교차검증은 사이킷런의 timesplt() 함수로 쉽게 구현 가능
# >>
# 1월 ~ 3월 데이터를 사용해 훈련, 4월 데이터 검증 후, 1월 ~ 4월 데이터 사용해 훈련 후 5월 데이터 검증
# >>
# 그러나, 데이터 누설(leakage) 발생
# >
# > --blocking walk forward 교차 훈련
# >>테스트셋 사이에 마진(margin)을 설정해 서로 곂치지 않도록함 -> 데이터 누설 발생 방지
#
#
# 2.   엠바고와 퍼징
# > -- 훈련셋과 검증셋 사이에 마진을 두고, 각 검증 단계에서 사용하는 훈련셋이겹치지 않도록 설정

# %% [markdown]
# *   5.4 금융에서의데이터 전처리
# > -- 원본 데이터를 모델이 학습하기 좋게 만들어 주는 작업(노이즈 제거)
# >>
# 벡터화, 정규화, 결측치 다루기, 특성 추출 등이 존재 하지만, 금융 데이터는 노이즈가 심하고 특성 수에 비해 상대적으로 시계열 데이터 길이가 짧다.
#
#
# 1.   노이즈를 줄이는 방법
# > 노이즈 제거란 불필요한 디테일을 없앰으로써 더 중요한 정보에 주목(압축, 차원축소)
#
# >> 1) 이동평균과 지수 이동 평균
#
# >> 2) 에이블릿 변환
#
# >> 3) PCA(Principal Component Analysis)
#
# >> 4) 딥러닝 기반의 노이즈 제거 - 오토인코더

# %% [markdown]
# *   5.5 머신러닝을 활용한 전략의 평가 지표
# > -- 분류 : 정확도, 정밀도, F1 점수, AUC-ROC 등
# >>
#    -- 회귀 : 평균 제곱 오차, 결정계수 등
#
# 1.   트랜드에 대한 가중치
# > 상승률에 따라 가중치를 달리 부여, 단순 이진 분류 문제를 다중 분류 문제로 변환
#
# 2.   레이블 데이터 불균형 문제
# > 분류 문제로 주식시장의 방향성을 예측할 때, 시장국면에 따라 레이블 데이터 불균형 발생->등락 횟수가 최대한 비슷하게 레이블링해야함..
# AUC-ROC 점수 같은 측정 지표를 잘 활용하는 것이 중요~
#
# 3.   다양한 지표 함께 보기

# %% [markdown]
# *   5.6 백테스팅
# > 특정 전략을 과거에 적용했을 때 어떠한 결과가 나오는지 시뮬레이션해보는 작업이나, 신뢰할 수 있는가는 난제임..그러므로 백테스팅의 함정을 피해갈 테크닉을 사용해 신뢰성 있는 결과를 만들어내는 것이 중요
#
#
# 1.   최대한 많은 경제적 시나리오를 포함하는 백테싕 기간 설정하기
# 2.   수수료와 슬리피지 고려하기
# 3.   편향 고려하기
# > -- 생존편향, 사전 관찰편향, 심리적 인내 편향
# 4.   특정 주가가 아닌 전체 자산 종류나 투자 영역에 대한 모델 개발하기
# 5.   여러 가지 지표 활용하기
# 6.   시계열 분석에 맞는 교차 검증 방법 활용하기

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
from sklearn.datasets import load_boston


boston = load_boston()

bostonDF = pd.DataFrame(boston.data , columns = boston.feature_names)
bostonDF.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %%
bostonDF['PRICE'] = boston.target


from sklearn.model_selection import train_test_split

y_target = bostonDF['PRICE']
X_data = bostonDF.drop(['PRICE'],axis=1,inplace=False)

X_train , X_test , y_train , y_test = train_test_split(X_data , y_target ,test_size=0.3, random_state=156)

# %%
bostonDF.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  PRICE
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
#
# [5 rows x 14 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

lr = LinearRegression()
lr.fit(X_train ,y_train )
y_preds = lr.predict(X_test)

# %%
print(y_preds)
# Out:
# [23.15424087 19.65590246 36.42005168 19.96705124 32.40150641 17.66341192
#  30.32844101 17.8513932  10.86187069 12.83177966 21.18350434 16.41212257
#  28.66817527 37.01110952 23.42172197 24.56906089 14.55434775 11.51023436
#  30.27784089 23.48027467 22.86210577 17.61623753 21.2528808  17.29802868
#  34.06118291  7.19879841 13.39928425 19.4234468  13.2423286   8.3336837
#  29.34933073 11.83768837 19.84125562 23.97623235 16.34351261 13.20973749
#  14.3352014  17.26323753 17.37091562 23.84644351 32.8390912   9.3866759
#  19.06694335 -3.98840206 19.87721947 21.26003361 24.17775745 35.35923599
#  20.32415303 28.23212889 32.67560962 40.83910565 41.19126206 19.78588457
#  25.0134137  24.13111046 19.62715719 33.49344219 23.61402811 15.31513017
#  22.70657074 25.78436589 23.99723589  8.78013424 21.81929237 39.68193998
#  32.8907251  30.20417723 14.35610647 23.56129992 13.6987184  32.17099211
#  36.43647957 27.41243794 21.43887413 29.94548936 20.80737308 26.76489459
# ...
