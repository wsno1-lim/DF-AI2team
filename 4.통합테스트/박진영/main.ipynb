# %%
from model import makeFeatures, makeMLModel, makeDLModel
from predict import readMe, backTesting, predictNext

# %%
readMe()
# Out:
# *** 아래 순서로 실행합니다. ***
#
# 1. 데이터 불러오기 : data = makeFeatures()
# 2. 머신러닝 모델 만들기 : makeMLModel(data)
# 3. 딥러닝 모델 만들기 : makeDLModel(data)
# 4. 만든 모델로 백테스팅 해보기 : backTesting()
# 5. 만든 모델로 Up/Down 예측하기 : predictNext()

# %%
data = makeFeatures()
# Out:
# 학습 및 테스트 데이터를 생성하고 있습니다.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 데이터 생성이 완료되었습니다.

# %%
makeMLModel(data)
# Out:
# 머신러닝 모델을 만듭니다.
#
# 학습 기간은 2012-05-09 부터 2020-04-01 까지입니다.
# 테스트 기간은 2020-04-02 부터 2021-02-19 까지입니다.
#
# KNeighborsClassifier 학습데이터셋 정확도: 0.7030
# KNeighborsClassifier 테스트셋 정확도: 0.5505
#
# SVC 학습데이터셋 정확도: 0.6207
# SVC 테스트셋 정확도: 0.5459
#
# RandomForestClassifier 학습데이터셋 정확도: 1.0000
# RandomForestClassifier 테스트셋 정확도: 0.5550
#
# GradientBoostingClassifier 학습데이터셋 정확도: 0.7602
# GradientBoostingClassifier 테스트셋 정확도: 0.5505
#
# XGBClassifier 학습데이터셋 정확도: 1.0000
# XGBClassifier 테스트셋 정확도: 0.5183
#
# LGBMClassifier 학습데이터셋 정확도: 1.0000
# LGBMClassifier 테스트셋 정확도: 0.5413
#
# RandomForestClassifier 의 테스트 정확도가 제일 높으므로, 해당 모델을 저장합니다.

# %%
makeDLModel(data)
# Out:
# 딥러닝 모델을 만듭니다.
#
# 학습 기간은 2012-05-09 부터 2020-04-01 까지입니다.
# 검증 기간은 2020-04-02 부터 2020-09-01 까지입니다.
# 테스트 기간은 2020-09-02 부터 2021-02-19 까지입니다.
#
# Up/Down 의 분포에 따른 정확도 기준값(최소 임계치)은 다음과 같습니다.
# train acc 기준값 : 0.5052000284194946
# val acc 기준값 : 0.5152000188827515
# test acc 기준값 : 0.5045999884605408
#
# 학습을 진행하고 있습니다. 이 작업은 5분 정도 걸립니다.
#
#  *** 학습 : epoch에 따른 loss 및 accuracy 변화 ***
#  *** 테스트 데이터의 ROC 커브 ***
# ROC AUC 값 : 0.6254
#
# ======= 테스트 셋 정확도 측정 =======
#
# 실제 true 인 것 중 모델이 true 라고 예측한 비율: 0.45
#
# 실제 false 인 것 중 모델이 false 라고 예측한 비율: 0.796
#
# 실제 false 인데 true 로 잘못 예측한 비율: 0.2
#
# 실제 true 인데 false 로 잘못 예측한 비율 : 0.55
#
# accuracy (정확도): 0.624

# %%
backTesting()
# Out:
# *** 삼성전자 익영업일 종가 UP/DOWN 예측에 따른 수익률 계산 ***
#
# 시작일을 입력하세요 EX) YYYY-MM-DD :
# 2020-09-05
# 종료일을 입력하세요 EX) YYYY-MM-DD :
# 2021-03-08
# 종료일을 조정합니다.
# 예측모델을 정해주세요 (ML / DL) :
# ML
# 시작일(영업일) : 2020-09-07
# 종료일(영업일) : 2021-03-05
# 예측모델 : ML
#
# *** 데이터 불러오는 중 ... ***
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ※ 데이터 중 누락된 부분이 있어, 이전 영업일 데이터 값으로 대체합니다.
#
#
# ※ 수익률 계산은 다음과 같은 가정 하에 수행됩니다.
#   1. 당일 종가 대비 익일 종가 변화율을 예측합니다.
#   2. 매매가 = 당일 종가 = 익일 시가라고 가정합니다.
#   3. 매매 수수료와 세금은 고려하지 않습니다.
#   4. 실제 주식 가격과 상관없이, 항상 현재 갖고있는 전체 자산을 투자한다고 가정합니다.
#   5. 변화율이 + 일 때는 Up, 0 이거나 - 일때는 Down 으로 표시합니다.
#
# Buy & Hold 했을 경우 수익률 : 45.13%
# 예측 최종 수익률 : 52.02%
#             보유상태  예측결과 매매상태  실제결과 실제당일종가 실제익일종가  실제변화율     잔고   주식계좌      수익률  \
# 시작             -     -    -     -      -      -      -  10000      -        -
# 2020-09-07   미보유  Down   유지    Up  56500  58700  +3.9%  10000      0     0.0%
# 2020-09-08   미보유  Down   유지  Down  58700  58400  -0.5%  10000      0     0.0%
# 2020-09-09   미보유    Up   매수    Up  58400  59200  +1.4%      0  10136   +1.36%
# 2020-09-10   보유   Down   매도  Down  59200  59000  -0.3%  10136      0   +1.36%
# ...          ...   ...  ...   ...    ...    ...    ...    ...    ...      ...
# 2021-02-26   미보유    Up   매수    Up  82500  83600  +1.3%      0  15202  +52.02%
# 2021-03-02   보유   Down   매도    Up  83600  84000  +0.5%  15202      0  +52.02%
# 2021-03-03   미보유  Down   유지  Down  84000  82400  -1.9%  15202      0  +52.02%
# 2021-03-04   미보유  Down   유지  Down  82400  82100  -0.4%  15202      0  +52.02%
# 2021-03-05   미보유  Down   유지  Down  82100  82000  -0.1%  15202      0  +52.02%
#
#              예측정확도
# 시작               -
# 2020-09-07    0.0%
# 2020-09-08   50.0%
# 2020-09-09  66.67%
# 2020-09-10   75.0%
# ...            ...
# 2021-02-26   56.9%
# 2021-03-02  56.41%
# 2021-03-03  56.78%
# 2021-03-04  57.14%
# 2021-03-05   57.5%
#
# [121 rows x 11 columns]

# %%
backTesting()
# Out:
# *** 삼성전자 익영업일 종가 UP/DOWN 예측에 따른 수익률 계산 ***
#
# 시작일을 입력하세요 EX) YYYY-MM-DD :
# 2020-09-05
# 종료일을 입력하세요 EX) YYYY-MM-DD :
# 2021-03-08
# 종료일을 조정합니다.
# 예측모델을 정해주세요 (ML / DL) :
# DL
# 시작일(영업일) : 2020-09-07
# 종료일(영업일) : 2021-03-05
# 예측모델 : DL
#
# *** 데이터 불러오는 중 ... ***
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ※ 데이터 중 누락된 부분이 있어, 이전 영업일 데이터 값으로 대체합니다.
#
#
# ※ 수익률 계산은 다음과 같은 가정 하에 수행됩니다.
#   1. 당일 종가 대비 익일 종가 변화율을 예측합니다.
#   2. 매매가 = 당일 종가 = 익일 시가라고 가정합니다.
#   3. 매매 수수료와 세금은 고려하지 않습니다.
#   4. 실제 주식 가격과 상관없이, 항상 현재 갖고있는 전체 자산을 투자한다고 가정합니다.
#   5. 변화율이 + 일 때는 Up, 0 이거나 - 일때는 Down 으로 표시합니다.
#
# Buy & Hold 했을 경우 수익률 : 45.13%
# 예측 최종 수익률 : 47.78%
#             보유상태  예측결과 예측강도 매매상태  실제결과 실제당일종가 실제익일종가  실제변화율     잔고   주식계좌  \
# 시작             -     -    -    -     -      -      -      -  10000      -
# 2020-09-07   미보유  Down    약   유지    Up  56500  58700  +3.9%  10000      0
# 2020-09-08   미보유  Down    약   유지  Down  58700  58400  -0.5%  10000      0
# 2020-09-09   미보유    Up    약   매수    Up  58400  59200  +1.4%      0  10136
# 2020-09-10   보유   Down    약   매도  Down  59200  59000  -0.3%  10136      0
# ...          ...   ...  ...  ...   ...    ...    ...    ...    ...    ...
# 2021-02-26   미보유  Down    약   유지    Up  82500  83600  +1.3%  14778      0
# 2021-03-02   미보유  Down    약   유지    Up  83600  84000  +0.5%  14778      0
# 2021-03-03   미보유  Down    강   유지  Down  84000  82400  -1.9%  14778      0
# 2021-03-04   미보유  Down    강   유지  Down  82400  82100  -0.4%  14778      0
# 2021-03-05   미보유  Down    약   유지  Down  82100  82000  -0.1%  14778      0
#
#                 수익률   예측정확도
# 시작                -       -
# 2020-09-07     0.0%    0.0%
# 2020-09-08     0.0%   50.0%
# 2020-09-09   +1.36%  66.67%
# 2020-09-10   +1.36%   75.0%
# ...             ...     ...
# 2021-02-26  +47.78%  62.07%
# 2021-03-02  +47.78%  61.54%
# 2021-03-03  +47.78%  61.86%
# 2021-03-04  +47.78%  62.18%
# 2021-03-05  +47.78%   62.5%
#
# [121 rows x 12 columns]

# %%
predictNext()
# Out:
# *** 2021-03-08 일자를 기준으로 다음 영업일의 종가 변화율을 예측합니다. ***
#
# *** 데이터 불러오는 중 ... ***
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ※ 데이터 중 누락된 부분이 있어, 이전 영업일 데이터 값으로 대체합니다.
#
# 머신러닝 모델로 예측한 결과는 Up 입니다.
#
# 딥러닝 모델로 예측한 결과는 Up(강한 예측) 입니다.
