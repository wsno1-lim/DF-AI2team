# %%
from model import makeFeatures, makeMLModel, makeDLModel
from predict import readMe, backTesting, predictNext
from get_feature_list import get_trading_trend, get_trading_trend_fix, get_feature_info_get, get_shift_feature, get_model_scaler, get_model_heatmap, get_graph

def predict_stock(mode) :
    if mode == "1" :
        data = makeFeatures() 
        makeMLModel(data)
        makeDLModel(data)
    elif mode == "2" :
        backTesting()    
    elif mode == "3" :
        predictNext()

    elif mode == "4" :
        print("분석리포트를 생성 중입니다.")
        samsung_etc = get_trading_trend_fix() 
        model_samsung = get_feature_info_get(samsung_etc)
        model_samsung = get_shift_feature(model_samsung)
        scaler_samsung = get_model_scaler(model_samsung)
        get_model_heatmap(scaler_samsung)
        get_graph(scaler_samsung)
              

def main():

    print("*** 아래 모드를 선택해주세요. ***\n")
    print("1. 데이터 불러오기")
    print("   머신러닝 모델 만들기")
    print("   딥러닝 모델 만들기")
    print("2. 만든 모델로 백테스팅 해보기")
    print("3. 만든 모델로 Up/Down 익일예측하기")  
    print("4. 분석리포트 만들기\n\n")  
    
    mode = input("모드를 입력해주세요 :")
    predict_stock(mode) 
 
main()
# Out:
# *** 아래 모드를 선택해주세요. ***
#
# 1. 데이터 불러오기
#    머신러닝 모델 만들기
#    딥러닝 모델 만들기
# 2. 만든 모델로 백테스팅 해보기
# 3. 만든 모델로 Up/Down 익일예측하기
# 4. 분석리포트 만들기
#
#
# 모드를 입력해주세요 :1
# 학습 및 테스트 데이터를 생성하고 있습니다.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 데이터 생성이 완료되었습니다.
#
# 머신러닝 모델을 만듭니다.
#
# 학습 기간은 2012-05-09 부터 2020-04-01 까지입니다.
# 테스트 기간은 2020-04-02 부터 2021-02-19 까지입니다.
#
# KNeighborsClassifier 학습데이터셋 정확도: 0.7030
# KNeighborsClassifier 테스트셋 정확도: 0.5505
#
# SVC 학습데이터셋 정확도: 0.6207
# SVC 테스트셋 정확도: 0.5459
#
# RandomForestClassifier 학습데이터셋 정확도: 1.0000
# RandomForestClassifier 테스트셋 정확도: 0.5229
#
# GradientBoostingClassifier 학습데이터셋 정확도: 0.7602
# GradientBoostingClassifier 테스트셋 정확도: 0.5505
#
# XGBClassifier 학습데이터셋 정확도: 1.0000
# XGBClassifier 테스트셋 정확도: 0.5183
#
# LGBMClassifier 학습데이터셋 정확도: 1.0000
# LGBMClassifier 테스트셋 정확도: 0.5413
#
# KNeighborsClassifier 의 테스트 정확도가 제일 높으므로, 해당 모델을 저장합니다.
#
# 딥러닝 모델을 만듭니다.
#
# 학습 기간은 2012-05-09 부터 2020-04-01 까지입니다.
# 검증 기간은 2020-04-02 부터 2020-09-01 까지입니다.
# 테스트 기간은 2020-09-02 부터 2021-02-19 까지입니다.
#
# Up/Down 의 분포에 따른 정확도 기준값(최소 임계치)은 다음과 같습니다.
# train acc 기준값 : 0.5052000284194946
# val acc 기준값 : 0.5152000188827515
# test acc 기준값 : 0.5045999884605408
#
# 학습을 진행하고 있습니다. 이 작업은 5분 정도 걸립니다.
#
#  *** 학습 : epoch에 따른 loss 및 accuracy 변화 ***
#  *** 테스트 데이터의 ROC 커브 ***
# ROC AUC 값 : 0.6434
#
# ======= 테스트 셋 정확도 측정 =======
#
# 실제 true 인 것 중 모델이 true 라고 예측한 비율: 0.51
#
# 실제 false 인 것 중 모델이 false 라고 예측한 비율: 0.778
#
# 실제 false 인데 true 로 잘못 예측한 비율: 0.22
#
# 실제 true 인데 false 로 잘못 예측한 비율 : 0.49
#
# accuracy (정확도): 0.642
