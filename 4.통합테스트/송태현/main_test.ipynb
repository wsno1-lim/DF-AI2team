# %%
from get_peakntopword import get_SAMSUNG_dataframe, get_SAMSUNG_Peaks, get_news, get_top_words

        
def main():   
    
    print("PEAK출력/TOP10 WORD를 생성 중입니다.")
    output,model_samsung = get_SAMSUNG_dataframe()
    get_SAMSUNG_Peaks(output)
    pivot_df = get_news()
    get_top_words(pivot_df, model_samsung,output)
 
main()
# Out:
# PEAK출력/TOP10 WORD를 생성 중입니다.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 네이버 기사를 가져옵니다.(약 5분 소요)
# 최대치 PEAK에서 TOP10 WORDS
# [('반도체', 46), ('돌파', 27), ('최고', 25), ('준법', 24), ('이재용', 23), ('목표', 22), ('신고', 20), ('투자', 19), ('코로나', 18), ('개미', 17)]
# 최저치 PEAK에서 TOP10 WORDS
# [('반도체', 40), ('이재용', 30), ('코로나', 27), ('사업', 24), ('하이닉스', 17), ('구속', 17), ('투자', 16), ('인텔', 15), ('그룹', 15), ('생산', 15)]
